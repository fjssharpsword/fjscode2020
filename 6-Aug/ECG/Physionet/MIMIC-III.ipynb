# %%
# coding:utf-8  
'''
@author: Jason.F
@data: 2019.08.16
@function: MIMIC-III database: https://mimic.physionet.org/
           schema of DB: https://mit-lcp.github.io/mimic-schema-spy/
           Github: https://github.com/MIT-LCP/mimic-code
'''
import numpy as np
import pandas as pd

'''
Table: PATIENTS
'''
filePath = "/data/fjsdata/physionet/MIMIC-III/PATIENTS.csv" 
data = pd.read_csv(filePath, sep=',')
data.head()
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0     234         249      F  2075-03-13 00:00:00                  NaN
# 1     235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2     236         251      M  2090-03-15 00:00:00                  NaN
# 3     237         252      M  2078-03-06 00:00:00                  NaN
# 4     238         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
'''
Table: CPTEVENTS
'''
filePath = "/data/fjsdata/physionet/MIMIC-III/CPTEVENTS.csv" 
data = pd.read_csv(filePath, sep=',')
data.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (4,5,7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ROW_ID  SUBJECT_ID  HADM_ID COSTCENTER CHARTDATE CPT_CD  CPT_NUMBER  \
# 0     317       11743   129545        ICU       NaN  99232     99232.0
# 1     318       11743   129545        ICU       NaN  99232     99232.0
# 2     319       11743   129545        ICU       NaN  99232     99232.0
# 3     320       11743   129545        ICU       NaN  99232     99232.0
# 4     321        6185   183725        ICU       NaN  99223     99223.0
#
#   CPT_SUFFIX  TICKET_ID_SEQ              SECTIONHEADER  \
# 0        NaN            6.0  Evaluation and management
# 1        NaN            7.0  Evaluation and management
# 2        NaN            8.0  Evaluation and management
# 3        NaN            9.0  Evaluation and management
# ...

# %%
'''
Table: DATETIMEEVENTS
'''
filePath = "/data/fjsdata/physionet/MIMIC-III/DATETIMEEVENTS.csv" 
data = pd.read_csv(filePath, sep=',')
data.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0     711        7657  121183.0    297945.0    3411  2172-03-14 11:00:00
# 1     712        7657  121183.0    297945.0    3411  2172-03-14 13:00:00
# 2     713        7657  121183.0    297945.0    3411  2172-03-14 15:00:00
# 3     714        7657  121183.0    297945.0    3411  2172-03-14 17:00:00
# 4     715        7657  121183.0    297945.0    3411  2172-03-14 19:00:00
#
#              STORETIME   CGID VALUE VALUEUOM  WARNING  ERROR  RESULTSTATUS  \
# 0  2172-03-14 11:52:00  16446   NaN     Date      NaN    NaN           NaN
# 1  2172-03-14 12:36:00  16446   NaN     Date      NaN    NaN           NaN
# ...

# %%
'''
Table: LABEVENTS
'''
filePath = "/data/fjsdata/physionet/MIMIC-III/LABEVENTS.csv" 
data = pd.read_csv(filePath, sep=',')
data.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ITEMID            CHARTTIME VALUE  VALUENUM  \
# 0     281           3      NaN   50820  2101-10-12 16:07:00  7.39      7.39
# 1     282           3      NaN   50800  2101-10-12 18:17:00   ART       NaN
# 2     283           3      NaN   50802  2101-10-12 18:17:00    -1     -1.00
# 3     284           3      NaN   50804  2101-10-12 18:17:00    22     22.00
# 4     285           3      NaN   50808  2101-10-12 18:17:00  0.93      0.93
#
#   VALUEUOM      FLAG
# 0    units       NaN
# 1      NaN       NaN
# 2    mEq/L       NaN
# 3    mEq/L       NaN
# 4   mmol/L  abnormal

# %%
'''
Table: NOTEEVENTS
'''
filePath = "/data/fjsdata/physionet/MIMIC-III/NOTEEVENTS.csv" 
data = pd.read_csv(filePath, sep=',')
data.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME  \
# 0     174       22532  167853.0  2151-08-04       NaN       NaN
# 1     175       13702  107527.0  2118-06-14       NaN       NaN
# 2     176       13702  167118.0  2119-05-25       NaN       NaN
# 3     177       13702  196489.0  2124-08-18       NaN       NaN
# 4     178       26880  135453.0  2162-03-25       NaN       NaN
#
#             CATEGORY DESCRIPTION  CGID  ISERROR  \
# 0  Discharge summary      Report   NaN      NaN
# 1  Discharge summary      Report   NaN      NaN
# 2  Discharge summary      Report   NaN      NaN
# 3  Discharge summary      Report   NaN      NaN
# 4  Discharge summary      Report   NaN      NaN
#
# ...
