# %%
import sys
import os
import math
import random
import heapq 
import time
import copy
import gc
import numpy as np
import pandas as pd
from functools import reduce
from scipy.spatial.distance import pdist
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
import baostock as bs#pip install baostock
import mplfinance as mpf #pip install mplfinance
from matplotlib.pylab import date2num
import datetime
torch.cuda.set_device(1)
print (torch.cuda.current_device())
# Out:
# 1

# %%
#Calculate MACD
def cal_macd_system(data,short_,long_,m):
    '''
    data=['Open','High','Low','Close','Volume']
    parameter: short_,long_,m
    return:data=['Open','High','Low','Close','Volume','diff','dea','macd']
    '''
    data['diff']=data['Close'].ewm(adjust=False,alpha=2/(short_+1),ignore_na=True).mean()-\
                data['Close'].ewm(adjust=False,alpha=2/(long_+1),ignore_na=True).mean()
    data['dea']=data['diff'].ewm(adjust=False,alpha=2/(m+1),ignore_na=True).mean()
    data['macd']=2*(data['diff']-data['dea'])
    return data
def macd_zero(macd):
    pos_signal, neg_signal = [],[]
    for idx,value in macd.iteritems():
        if value > 0:
            pos_signal.append(value)
            neg_signal.append(np.nan)
        else:
            neg_signal.append(value)
            pos_signal.append(np.nan)
    return pos_signal,neg_signal

#generate market chart
lg = bs.login() #login

#read hs300 stocks
rs = bs.query_hs300_stocks() 
hs300_stocks = []
while (rs.error_code == '0') & rs.next():
    hs300_stocks.append(rs.get_row_data())
#read k data
fields= "Date,Code,Open,High,Low,Close,Volume"
period = 160 #20 days
for stock_info in hs300_stocks:
    code=stock_info[1]
    rs = bs.query_history_k_data(code=code, fields=fields, \
                                 start_date='2019-07-01', end_date='2020-03-15', frequency="30",adjustflag="3") 
    data_list = []
    while (rs.error_code == '0') & rs.next():
        data_list.append(rs.get_row_data())
    result = pd.DataFrame(data_list, columns=rs.fields)
    result=result.apply(pd.to_numeric, errors='ignore')
    result = result[['Open','High','Low','Close','Volume']]
    for i in range(result.shape[0]//period): #8 samples per day (30 minutes and 4 hours per day)
        img = result[i*period:(i+1)*period].reset_index(drop=True)
        img.index=pd.to_datetime(img.index)#turn index to datatime
        img = cal_macd_system(img,12,26,9)
        pos_macd, neg_macd  = macd_zero(img['macd']) 
        apds = [ mpf.make_addplot(img['diff'],panel='lower',color='b'),
                 mpf.make_addplot(img['dea'],panel='lower',color='y'),
                 mpf.make_addplot(pos_macd,panel='lower',color='r',scatter=True),
                 mpf.make_addplot(neg_macd,panel='lower',color='g',scatter=True)
               ]
        kwargs = dict(type='candle',figratio =(16,8),volume=False,figscale=1)#line，mav=(5,10)
        save = dict(fname='/data/fjsdata/qtsys/img/'+code+'-'+str(i)+'.png',dpi=100, pad_inches=0.2)
        mpf.plot(img,**kwargs,addplot=apds,style='sas',savefig=save)#charles
        plt.close()
        sys.stdout.write('\r {} / {} '.format(i, result.shape[0]//period))
        sys.stdout.flush()
    print('Stock:%s completed!'%(stock_info[2]))
bs.logout()#logout
# Out:
# login success!
#  7 / 8 Stock:浦发银行 completed!
#  7 / 8 Stock:白云机场 completed!
#  7 / 8 Stock:上海机场 completed!
#  7 / 8 Stock:包钢股份 completed!
#  7 / 8 Stock:华能国际 completed!
#  7 / 8 Stock:华夏银行 completed!
#  7 / 8 Stock:民生银行 completed!
#  7 / 8 Stock:上港集团 completed!
#  7 / 8 Stock:宝钢股份 completed!
#  7 / 8 Stock:浙能电力 completed!
#  7 / 8 Stock:华能水电 completed!
#  7 / 8 Stock:华电国际 completed!
#  7 / 8 Stock:中国石化 completed!
#  7 / 8 Stock:南方航空 completed!
#  7 / 8 Stock:中信证券 completed!
#  7 / 8 Stock:三一重工 completed!
#  7 / 8 Stock:招商银行 completed!
#  7 / 8 Stock:中直股份 completed!
#  7 / 8 Stock:保利地产 completed!
#  7 / 8 Stock:中国联通 completed!
#  7 / 8 Stock:国投资本 completed!
#  7 / 8 Stock:宇通客车 completed!
#  7 / 8 Stock:葛洲坝 completed!
#  7 / 8 Stock:同仁堂 completed!
#  7 / 8 Stock:特变电工 completed!
#  7 / 8 Stock:同方股份 completed!
#  7 / 8 Stock:上汽集团 completed!
#  7 / 8 Stock:国金证券 completed!
#  7 / 8 Stock:北方稀土 completed!
#  7 / 8 Stock:东方航空 completed!
#  7 / 8 Stock:中国卫星 completed!
#  7 / 8 Stock:建发股份 completed!
#  7 / 8 Stock:上海建工 completed!
#  7 / 8 Stock:中国巨石 completed!
#  7 / 8 Stock:雅戈尔 completed!
#  7 / 8 Stock:兖州煤业 completed!
#  7 / 8 Stock:复星医药 completed!
#  7 / 8 Stock:新湖中宝 completed!
#  7 / 8 Stock:南山铝业 completed!
#  7 / 8 Stock:海航控股 completed!
#  7 / 8 Stock:圆通速递 completed!
#  7 / 8 Stock:航天信息 completed!
#  7 / 8 Stock:恒瑞医药 completed!
#  7 / 8 Stock:广汇汽车 completed!
#  7 / 8 Stock:安迪苏 completed!
#  7 / 8 Stock:万华化学 completed!
#  7 / 8 Stock:白云山 completed!
#  7 / 8 Stock:中油工程 completed!
#  7 / 8 Stock:华夏幸福 completed!
#  7 / 8 Stock:恒力石化 completed!
#  7 / 8 Stock:浙江龙盛 completed!
#  7 / 8 Stock:江西铜业 completed!
#  7 / 8 Stock:西南证券 completed!
#  7 / 8 Stock:中航电子 completed!
#  7 / 8 Stock:金地集团 completed!
#  7 / 8 Stock:五矿资本 completed!
#  7 / 8 Stock:海澜之家 completed!
#  7 / 8 Stock:国电南瑞 completed!
#  7 / 8 Stock:小商品城 completed!
#  7 / 8 Stock:片仔癀 completed!
#  7 / 8 Stock:通威股份 completed!
#  7 / 8 Stock:中国动力 completed!
#  7 / 8 Stock:亨通光电 completed!
#  7 / 8 Stock:中金黄金 completed!
#  7 / 8 Stock:烽火通信 completed!
#  7 / 8 Stock:方大炭素 completed!
#  7 / 8 Stock:贵州茅台 completed!
#  7 / 8 Stock:中天科技 completed!
#  7 / 8 Stock:天士力 completed!
#  7 / 8 Stock:山东黄金 completed!
#  7 / 8 Stock:济川药业 completed!
#  7 / 8 Stock:恒生电子 completed!
#  7 / 8 Stock:海油工程 completed!
#  7 / 8 Stock:海螺水泥 completed!
#  7 / 8 Stock:用友网络 completed!
#  7 / 8 Stock:绿地控股 completed!
#  7 / 8 Stock:东方明珠 completed!
#  7 / 8 Stock:福耀玻璃 completed!
#  7 / 8 Stock:陆家嘴 completed!
#  7 / 8 Stock:川投能源 completed!
#  7 / 8 Stock:上海石化 completed!
#  7 / 8 Stock:海尔智家 completed!
#  7 / 8 Stock:三安光电 completed!
#  7 / 8 Stock:物产中大 completed!
#  7 / 8 Stock:中航资本 completed!
#  7 / 8 Stock:北汽蓝谷 completed!
#  7 / 8 Stock:华域汽车 completed!
#  7 / 8 Stock:中航沈飞 completed!
#  7 / 8 Stock:国电电力 completed!
#  7 / 8 Stock:山西汾酒 completed!
#  7 / 8 Stock:安信信托 completed!
#  7 / 8 Stock:海通证券 completed!
#  7 / 8 Stock:通化东宝 completed!
#  7 / 8 Stock:国投电力 completed!
#  7 / 8 Stock:伊利股份 completed!
#  7 / 8 Stock:航发动力 completed!
#  7 / 8 Stock:长江电力 completed!
#  7 / 8 Stock:江苏银行 completed!
#  7 / 8 Stock:杭州银行 completed!
#  7 / 8 Stock:东方证券 completed!
#  7 / 8 Stock:中国电影 completed!
#  7 / 8 Stock:九州通 completed!
#  7 / 8 Stock:招商证券 completed!
#  7 / 8 Stock:大秦铁路 completed!
#  7 / 8 Stock:南京银行 completed!
#  7 / 8 Stock:隆基股份 completed!
#  7 / 8 Stock:宁波港 completed!
#  7 / 8 Stock:春秋航空 completed!
#  7 / 8 Stock:中信建投 completed!
#  7 / 8 Stock:中国神华 completed!
#  7 / 8 Stock:财通证券 completed!
#  7 / 8 Stock:中国国航 completed!
#  7 / 8 Stock:中国化学 completed!
#  7 / 8 Stock:工业富联 completed!
#  7 / 8 Stock:新城控股 completed!
#  7 / 8 Stock:天风证券 completed!
#  7 / 8 Stock:兴业银行 completed!
#  7 / 8 Stock:北京银行 completed!
#  7 / 8 Stock:中国铁建 completed!
#  7 / 8 Stock:东兴证券 completed!
#  7 / 8 Stock:国泰君安 completed!
#  7 / 8 Stock:白银有色 completed!
#  7 / 8 Stock:君正集团 completed!
#  7 / 8 Stock:陕西煤业 completed!
#  7 / 8 Stock:广州港 completed!
#  7 / 8 Stock:上海银行 completed!
#  7 / 8 Stock:广汽集团 completed!
#  7 / 8 Stock:农业银行 completed!
#  7 / 8 Stock:青岛港 completed!
#  7 / 8 Stock:中国平安 completed!
#  7 / 8 Stock:中国人保 completed!
#  7 / 8 Stock:交通银行 completed!
#  7 / 8 Stock:新华保险 completed!
#  7 / 8 Stock:三六零 completed!
#  7 / 8 Stock:兴业证券 completed!
#  7 / 8 Stock:中国中铁 completed!
#  7 / 8 Stock:工商银行 completed!
#  7 / 8 Stock:东吴证券 completed!
#  7 / 8 Stock:长沙银行 completed!
#  7 / 8 Stock:中国铝业 completed!
#  7 / 8 Stock:中国太保 completed!
#  7 / 8 Stock:上海医药 completed!
#  7 / 8 Stock:中国中冶 completed!
#  7 / 8 Stock:中国人寿 completed!
#  7 / 8 Stock:长城汽车 completed!
#  7 / 8 Stock:中国建筑 completed!
#  7 / 8 Stock:中国电建 completed!
#  7 / 8 Stock:华泰证券 completed!
#  7 / 8 Stock:上海电气 completed!
#  7 / 8 Stock:中国中车 completed!
#  7 / 8 Stock:光大证券 completed!
#  7 / 8 Stock:中国交建 completed!
#  7 / 8 Stock:中海油服 completed!
#  7 / 8 Stock:光大银行 completed!
#  7 / 8 Stock:美凯龙 completed!
#  7 / 8 Stock:成都银行 completed!
#  7 / 8 Stock:中国石油 completed!
#  7 / 8 Stock:正泰电器 completed!
#  7 / 8 Stock:浙商证券 completed!
#  7 / 8 Stock:中国银河 completed!
#  7 / 8 Stock:中国国旅 completed!
#  7 / 8 Stock:中煤能源 completed!
#  7 / 8 Stock:紫金矿业 completed!
#  7 / 8 Stock:方正证券 completed!
#  7 / 8 Stock:中远海控 completed!
#  7 / 8 Stock:永辉超市 completed!
#  7 / 8 Stock:建设银行 completed!
#  7 / 8 Stock:中国核电 completed!
#  7 / 8 Stock:中国银行 completed!
#  7 / 8 Stock:中国重工 completed!
#  7 / 8 Stock:金隅集团 completed!
#  7 / 8 Stock:贵阳银行 completed!
#  7 / 8 Stock:中信银行 completed!
#  7 / 8 Stock:中科曙光 completed!
#  7 / 8 Stock:养元饮品 completed!
#  7 / 8 Stock:汇顶科技 completed!
#  7 / 8 Stock:药明康德 completed!
#  7 / 8 Stock:合盛硅业 completed!
#  7 / 8 Stock:海天味业 completed!
#  7 / 8 Stock:华友钴业 completed!
#  7 / 8 Stock:欧派家居 completed!
#  7 / 8 Stock:步长制药 completed!
#  7 / 8 Stock:兆易创新 completed!
#  7 / 8 Stock:洛阳钼业 completed!
#  7 / 8 Stock:平安银行 completed!
#  7 / 8 Stock:万科A completed!
#  7 / 8 Stock:中兴通讯 completed!
#  7 / 8 Stock:华侨城A completed!
#  7 / 8 Stock:TCL集团 completed!
#  7 / 8 Stock:中联重科 completed!
#  7 / 8 Stock:申万宏源 completed!
#  7 / 8 Stock:美的集团 completed!
#  7 / 8 Stock:潍柴动力 completed!
#  7 / 8 Stock:金融街 completed!
#  7 / 8 Stock:藏格控股 completed!
#  6 / 7 Stock:东旭光电 completed!
#  7 / 8 Stock:渤海租赁 completed!
#  7 / 8 Stock:东阿阿胶 completed!
#  7 / 8 Stock:徐工机械 completed!
#  7 / 8 Stock:云南白药 completed!
#  7 / 8 Stock:安道麦A completed!
#  7 / 8 Stock:泸州老窖 completed!
#  7 / 8 Stock:古井贡酒 completed!
#  7 / 8 Stock:长安汽车 completed!
#  7 / 8 Stock:天茂集团 completed!
#  7 / 8 Stock:攀钢钒钛 completed!
#  7 / 8 Stock:铜陵有色 completed!
#  7 / 8 Stock:格力电器 completed!
#  7 / 8 Stock:金科股份 completed!
#  7 / 8 Stock:长春高新 completed!
#  7 / 8 Stock:阳光城 completed!
#  7 / 8 Stock:恒逸石化 completed!
#  7 / 8 Stock:河钢股份 completed!
#  7 / 8 Stock:京东方A completed!
#  7 / 8 Stock:国元证券 completed!
#  7 / 8 Stock:中航飞机 completed!
#  7 / 8 Stock:广发证券 completed!
#  7 / 8 Stock:长江证券 completed!
#  7 / 8 Stock:北新建材 completed!
#  7 / 8 Stock:五粮液 completed!
#  7 / 8 Stock:新希望 completed!
#  7 / 8 Stock:双汇发展 completed!
#  7 / 8 Stock:鞍钢股份 completed!
#  7 / 8 Stock:紫光股份 completed!
#  7 / 8 Stock:中南建设 completed!
#  7 / 8 Stock:华东医药 completed!
#  7 / 8 Stock:招商蛇口 completed!
#  7 / 8 Stock:新和成 completed!
#  7 / 8 Stock:华兰生物 completed!
#  7 / 8 Stock:大族激光 completed!
#  7 / 8 Stock:传化智联 completed!
#  7 / 8 Stock:苏宁易购 completed!
#  7 / 8 Stock:分众传媒 completed!
#  7 / 8 Stock:苏泊尔 completed!
#  7 / 8 Stock:美年健康 completed!
#  7 / 8 Stock:三花智控 completed!
#  7 / 8 Stock:东华软件 completed!
#  7 / 8 Stock:金螳螂 completed!
#  7 / 8 Stock:韵达股份 completed!
#  7 / 8 Stock:宁波银行 completed!
#  7 / 8 Stock:荣盛发展 completed!
#  7 / 8 Stock:石基信息 completed!
#  7 / 8 Stock:中航光电 completed!
#  7 / 8 Stock:金风科技 completed!
#  7 / 8 Stock:科大讯飞 completed!
#  7 / 8 Stock:大华股份 completed!
#  7 / 8 Stock:歌尔股份 completed!
#  7 / 8 Stock:上海莱士 completed!
#  7 / 8 Stock:东方雨虹 completed!
#  7 / 8 Stock:信立泰 completed!
#  7 / 8 Stock:洋河股份 completed!
#  7 / 8 Stock:东方园林 completed!
#  7 / 8 Stock:海大集团 completed!
#  7 / 8 Stock:顺丰控股 completed!
#  7 / 8 Stock:广联达 completed!
#  7 / 8 Stock:延安必康 completed!
#  7 / 8 Stock:海康威视 completed!
#  7 / 8 Stock:科伦药业 completed!
#  7 / 8 Stock:欧菲光 completed!
#  7 / 8 Stock:赣锋锂业 completed!
#  7 / 8 Stock:天齐锂业 completed!
#  7 / 8 Stock:申通快递 completed!
#  7 / 8 Stock:立讯精密 completed!
#  7 / 8 Stock:荣盛石化 completed!
#  7 / 8 Stock:老板电器 completed!
#  7 / 8 Stock:三七互娱 completed!
#  7 / 8 Stock:巨人网络 completed!
#  7 / 8 Stock:比亚迪 completed!
#  7 / 8 Stock:龙蟒佰利 completed!
#  7 / 8 Stock:世纪华通 completed!
#  7 / 8 Stock:完美世界 completed!
#  7 / 8 Stock:光启技术 completed!
#  7 / 8 Stock:西部证券 completed!
#  7 / 8 Stock:牧原股份 completed!
#  7 / 8 Stock:国信证券 completed!
#  7 / 8 Stock:万达电影 completed!
#  7 / 8 Stock:康弘药业 completed!
#  7 / 8 Stock:盈趣科技 completed!
#  7 / 8 Stock:鹏鼎控股 completed!
#  7 / 8 Stock:长城证券 completed!
#  7 / 8 Stock:华林证券 completed!
#  7 / 8 Stock:乐普医疗 completed!
#  7 / 8 Stock:爱尔眼科 completed!
#  7 / 8 Stock:网宿科技 completed!
#  7 / 8 Stock:机器人 completed!
#  7 / 8 Stock:同花顺 completed!
#  7 / 8 Stock:东方财富 completed!
#  7 / 8 Stock:碧水源 completed!
#  7 / 8 Stock:三聚环保 completed!
#  7 / 8 Stock:智飞生物 completed!
#  7 / 8 Stock:汇川技术 completed!
#  7 / 8 Stock:信维通信 completed!
#  7 / 8 Stock:沃森生物 completed!
#  7 / 8 Stock:宋城演艺 completed!
#  7 / 8 Stock:光线传媒 completed!
#  7 / 8 Stock:利亚德 completed!
#  7 / 8 Stock:三环集团 completed!
#  7 / 8 Stock:芒果超媒 completed!
#  7 / 8 Stock:蓝思科技 completed!
#  7 / 8 Stock:温氏股份 completed!
# logout success!

# %%
qt_dir = '/data/fjsdata/qtsys/img/' #the path of images
data = []
for iname in os.listdir(qt_dir):
    data.append([iname,''])
df = pd.DataFrame(data,columns=['name','label'])
df.to_csv('/data/fjsdata/qtsys/label.csv',index=False)
data = pd.read_csv('/data/fjsdata/qtsys/label.csv') 
print(data)
# Out:
#                  name  label
# 0     sh.600000-0.png    NaN
# 1     sh.600000-1.png    NaN
# 2     sh.600000-2.png    NaN
# 3     sh.600000-3.png    NaN
# 4     sh.600000-4.png    NaN
# ...               ...    ...
# 2395  sz.300498-4.png    NaN
# 2396  sz.300498-5.png    NaN
# 2397  sz.300498-6.png    NaN
# 2398  sz.300498-7.png    NaN
# 2399  sh.600360-0.png    NaN
#
# [2400 rows x 2 columns]

# %%
lg = bs.login()
fields= "Date,Code,Open,High,Low,Close,Volume"
rs = bs.query_history_k_data(code="sh.600360", fields=fields, start_date='2020-02-17', end_date='2020-03-15', frequency="30",adjustflag="3") 
data_list = []
while (rs.error_code == '0') & rs.next():
    data_list.append(rs.get_row_data())
result = pd.DataFrame(data_list, columns=rs.fields)
result=result.apply(pd.to_numeric, errors='ignore')
result.index=pd.to_datetime(result.index)
#result=result.reset_index()
result = result[['Open','High','Low','Close','Volume']]
print (result.shape)
#get MACD
def cal_macd_system(data,short_,long_,m):
    '''
    data=['Open','High','Low','Close','Volume']
    parameter: short_,long_,m
    return:data=['Open','High','Low','Close','Volume','diff','dea','macd']
    '''
    data['diff']=data['Close'].ewm(adjust=False,alpha=2/(short_+1),ignore_na=True).mean()-\
                data['Close'].ewm(adjust=False,alpha=2/(long_+1),ignore_na=True).mean()
    data['dea']=data['diff'].ewm(adjust=False,alpha=2/(m+1),ignore_na=True).mean()
    data['macd']=2*(data['diff']-data['dea'])
    return data
result = cal_macd_system(result,12,26,9)
def macd_zero(macd):
    pos_signal, neg_signal = [],[]
    for idx,value in macd.iteritems():
        if value > 0:
            pos_signal.append(value)
            neg_signal.append(np.nan)
        else:
            neg_signal.append(value)
            pos_signal.append(np.nan)
    return pos_signal,neg_signal
pos_macd, neg_macd  = macd_zero(result['macd']) 
#plot k line : 
#https://pypi.org/project/mplfinance/  
#https://github.com/matplotlib/mplfinance
apds = [ mpf.make_addplot((result[['diff']]),panel='lower',color='b'),
         mpf.make_addplot((result[['dea']]),panel='lower',color='y'),
         mpf.make_addplot(pos_macd,panel='lower',color='r',scatter=True),
        mpf.make_addplot(neg_macd,panel='lower',color='g',scatter=True)
       ]
kwargs = dict(type='candle',figratio =(16,8),volume=False,figscale=1)#line，mav=(5,10)
save = dict(fname='/data/fjsdata/qtsys/sh.600036-8.png',dpi=100, pad_inches=0.2)
mpf.plot(result,**kwargs,addplot=apds,style='sas',savefig=save)#charles
# Out:
# login success!
# (160, 5)

# %%
#http://baostock.com/baostock/index.php/Python_API
lg = bs.login()
fields= "date,code,open,high,low,close"
rs = bs.query_history_k_data("sz.000651", fields, start_date='2020-03-02', end_date='2020-03-08', frequency="5", adjustflag="2") 
data_list = []
while (rs.error_code == '0') & rs.next():
    data_list.append(rs.get_row_data())
result = pd.DataFrame(data_list, columns=rs.fields)
#result.index=pd.to_datetime(result.date)
#bs.logout() #exit

#print (result.info())
result=result.apply(pd.to_numeric, errors='ignore') #trun object to numeric
print(result.head())
print(result.shape)

result.close.plot(figsize=(8,6))  
plt.axis('off')
plt.savefig('/data/tmpexec/qt/H2',dpi=200) #(1600=8*200,1200=6*200)
plt.show()
# Out:
# login success!
#          date       code   open   high    low  close
# 0  2020-03-02  sz.000651  59.10  59.87  59.02  59.61
# 1  2020-03-02  sz.000651  59.56  59.60  59.20  59.24
# 2  2020-03-02  sz.000651  59.22  59.30  59.01  59.06
# 3  2020-03-02  sz.000651  59.06  59.07  58.70  58.90
# 4  2020-03-02  sz.000651  58.89  59.25  58.87  59.18
# (240, 6)

# %%
#pip install tushare
#pip install pyecharts==0.1.9.4
#pip install baostock
import baostock as bs
import tushare as ts
import pandas as pd  
import matplotlib.pyplot as plt
from pylab import mpl
from pyecharts import Kline
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False
tstoken='0519574f81c944a6ff254f438d4e76433dde0265bd064b7d961c240e' #youer token
ts.set_token(tstoken)

# %%
#initiate pro api, if token is not saved at local,ts.pro_api(tstoken) can be used as temp token
pro = ts.pro_api()
#https://tushare.pro/document/2?doc_id=25
#basic=pro.stock_basic(list_status='L',exchange='SZSE') #not permit
#print(basic.head())
pa=pro.daily(ts_code='000001.SZ', start_date='20200101',end_date='20200130')
pa.index=pd.to_datetime(pa.trade_date)
pa=pa.sort_index()
t=pa.index
x=list(t.strftime('%Y%m%d')) #x aixs
y=list(pa.loc[:,['open','close','low','high']].values) #y axis
kline = Kline("000001-Kline",title_text_size=15)
kline.add("Day Kline", x, y,
         is_datazoom_show=True,
         mark_line=["average"],
         mark_point=["max", "min"],
         mark_point_symbolsize=60,
         mark_line_valuedim=['highest', 'lowest'] )
kline.render()
