# %%
import numpy as np
import matplotlib.pyplot as plt

x = [5,10,15,20]
plt.figure(figsize=(12,10))

# 1
plt.subplot(2, 3, 1)
lsh = plt.plot(x,[0.3265,0.3198,0.3123,0.3070],'b-v',label='LSH')
dpsh = plt.plot(x,[0.4368,0.4080,0.3876,0.3766],'g-v',label='DPSH')
dsh = plt.plot(x,[0.5391,0.4312,0.3778,0.3490],'k-v',label='DSH')
drh = plt.plot(x,[0.6628,0.6050,0.5686,0.5402],'y-v',label='DRH')
ash = plt.plot(x,[0.8288,0.7561,0.6950,0.6544],'r-^',label='ASH')
plt.xticks(x)
plt.ylabel('ASOCT-Cataract')
plt.title('mHR@12')
plt.legend()
# 2
plt.subplot(2, 3, 2)
lsh = plt.plot(x,[0.2206,0.2146,0.2061,0.2006],'b-v',label='LSH')
dpsh = plt.plot(x,[0.3368,0.2785,0.2462,0.2262],'g-v',label='DPSH')
dsh = plt.plot(x,[0.4950,0.3583,0.2888,0.2476],'k-v',label='DSH')
drh = plt.plot(x,[0.5920,0.5023,0.4477,0.4099],'y-v',label='DRH')
ash = plt.plot(x,[0.7985,0.7000,0.6240,0.5706],'r-^',label='ASH')
plt.xticks(x)
plt.title('mAP@12')
plt.legend()
# 3
plt.subplot(2, 3, 3)
lsh = plt.plot(x,[0.6379,0.5789,0.5603,0.5499],'b-v',label='LSH')
dpsh = plt.plot(x,[0.7276,0.6774,0.6688,0.6636],'g-v',label='DPSH')
dsh = plt.plot(x,[0.8994,0.8532,0.8317,0.8238],'k-v',label='DSH')
drh = plt.plot(x,[0.8735,0.8479,0.8436,0.8413],'y-v',label='DRH')
ash = plt.plot(x,[0.9635,0.9563,0.9551,0.9525],'r-^',label='ASH')
plt.xticks(x)
plt.title('mRR@12')
plt.legend()
# 4
plt.subplot(2, 3, 4)
lsh = plt.plot(x,[0.4676,0.4624,0.4609,0.4612],'b-v',label='LSH')
dpsh = plt.plot(x,[0.6128,0.6188,0.6170,0.6178],'g-v',label='DPSH')
dsh = plt.plot(x,[0.6380,0.6331,0.6345,0.6352],'k-v',label='DSH')
drh = plt.plot(x,[0.6490,0.6392,0.6395,0.6418],'y-v',label='DRH')
ash = plt.plot(x,[0.6970,0.6977,0.6964,0.6968],'r-^',label='ASH')
plt.xticks(x)
plt.ylabel('Fundus-iSee')
plt.title('mHR@12')
plt.legend()
# 5
plt.subplot(2, 3, 5)
lsh = plt.plot(x,[0.3986,0.3828,0.3715,0.3654],'b-v',label='LSH')
dpsh = plt.plot(x,[0.5362,0.5154,0.5034,0.4983],'g-v',label='DPSH')
dsh = plt.plot(x,[0.5664,0.5399,0.5301,0.5253],'k-v',label='DSH')
drh = plt.plot(x,[0.5716,0.5428,0.5326,0.5288],'y-v',label='DRH')
ash = plt.plot(x,[0.6490,0.6346,0.6272,0.6233],'r-^',label='ASH')
plt.xticks(x)
plt.title('mAP@12')
plt.legend()
# 6
plt.subplot(2, 3, 6)
lsh = plt.plot(x,[0.6882,0.6455,0.6293,0.6118],'b-v',label='LSH')
dpsh = plt.plot(x,[0.8576,0.8229,0.7928,0.7809],'g-v',label='DPSH')
dsh = plt.plot(x,[0.8666,0.8341,0.7992,0.7879],'k-v',label='DSH')
drh = plt.plot(x,[0.8525,0.8243,0.7986,0.7883],'y-v',label='DRH')
ash = plt.plot(x,[0.8986,0.8707,0.8600,0.8429],'r-^',label='ASH')
plt.xticks(x)
plt.title('mRR@12')
plt.legend()


plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [12,24,36,48]
plt.figure(figsize=(12,10))

# 1
plt.subplot(2, 3, 1)
lsh = plt.plot(x,[0.2598,0.2617,0.2817,0.2884],'k-v',label='LSH')
mhf = plt.plot(x,[0.3568,0.3637,0.3812,0.3886],'c-v',label='MHF')
dpsh = plt.plot(x,[0.5080,0.5202,0.5235,0.5380],'g-v',label='DPSH')
dpsha = plt.plot(x,[0.4564,0.4612,0.4767,0.4807],'g--v',label='DPSH-A')
dsh = plt.plot(x,[0.5312,0.5544,0.5621,0.5700],'b-v',label='DSH')
dsha = plt.plot(x,[0.5435,0.5768,0.5841,0.5907],'b--v',label='DSH-A')
drh = plt.plot(x,[0.6050,0.6338,0.6391,0.6572],'y-v',label='DRH')
ash = plt.plot(x,[0.7061,0.7332,0.7384,0.7480],'r-^',label='ASH-U(our)')
plt.xticks(x)
plt.ylabel('ASOCT-Cataract')
plt.title('mHR')
plt.legend()
# 2
plt.subplot(2, 3, 2)
lsh = plt.plot(x,[0.1846,0.2020,0.2142,0.2180],'k-v',label='LSH')
mhf = plt.plot(x,[0.2068,0.2237,0.2312,0.2486],'c-v',label='MHF')
dpsh = plt.plot(x,[0.3785,0.3855,0.3935,0.3948],'g-v',label='DPSH')
dpsha = plt.plot(x,[0.3564,0.3612,0.3667,0.3707],'g--v',label='DPSH-A')
dsh = plt.plot(x,[0.4583,0.4631,0.4720,0.4749],'b-v',label='DSH')
dsha = plt.plot(x,[0.4835,0.4968,0.5041,0.5297],'b--v',label='DSH-A')
drh = plt.plot(x,[0.6023,0.6170,0.6260,0.6304],'y-v',label='DRH')
ash = plt.plot(x,[0.7000,0.7133,0.7230,0.7361],'r-^',label='ASH-U(our)')
plt.xticks(x)
plt.title('mAP')
plt.legend()
# 3
plt.subplot(2, 3, 3)
lsh = plt.plot(x,[0.4789,0.5057,0.5342,0.5570],'k-v',label='LSH')
mhf = plt.plot(x,[0.5668,0.5737,0.5812,0.6186],'c-v',label='MHF')
dpsh = plt.plot(x,[0.6674,0.6794,0.7268,0.7443],'g-v',label='DPSH')
dpsha = plt.plot(x,[0.6064,0.6212,0.6367,0.6507],'g--v',label='DPSH-A')
dsh = plt.plot(x,[0.7532,0.8195,0.8206,0.8451],'b-v',label='DSH')
dsha = plt.plot(x,[0.7935,0.8268,0.8341,0.8497],'b--v',label='DSH-A')
drh = plt.plot(x,[0.8479,0.8614,0.8768,0.9051],'y-v',label='DRH')
ash = plt.plot(x,[0.9263,0.9367,0.9589,0.9619],'r-^',label='ASH-U(our)')
plt.xticks(x)
plt.title('mRR')
plt.legend()
# 4
plt.subplot(2, 3, 4)
lsh = plt.plot(x,[0.4624,0.4682,0.4729,0.4751],'k-v',label='LSH')
mhf = plt.plot(x,[0.5068,0.5137,0.5212,0.5286],'c-v',label='MHF')
dpsh = plt.plot(x,[0.6188,0.6298,0.6340,0.6440],'g-v',label='DPSH')
dpsha = plt.plot(x,[0.5912,0.5964,0.6067,0.6107],'g--v',label='DPSH-A')
dsh = plt.plot(x,[0.6331,0.6367,0.6455,0.6529],'b-v',label='DSH')
dsha = plt.plot(x,[0.6535,0.6568,0.6641,0.6797],'b--v',label='DSH-A')
drh = plt.plot(x,[0.6392,0.6434,0.6564,0.6577],'y-v',label='DRH')
ash = plt.plot(x,[0.6977,0.6901,0.7209,0.7270],'r-^',label='ASH-L(our)')
plt.xticks(x)
plt.ylabel('Fundus-iSee')
plt.title('mHR')
plt.legend()
# 5
plt.subplot(2, 3, 5)
lsh = plt.plot(x,[0.3828,0.4091,0.4135,0.4236],'k-v',label='LSH')
mhf = plt.plot(x,[0.4168,0.4337,0.4412,0.4486],'c-v',label='MHF')
dpsh = plt.plot(x,[0.5154,0.5379,0.5512,0.5612],'g-v',label='DPSH')
dpsha = plt.plot(x,[0.5001,0.5112,0.5167,0.5207],'g--v',label='DPSH-A')
dsh = plt.plot(x,[0.5299,0.5410,0.5521,0.5614],'b-v',label='DSH')
dsha = plt.plot(x,[0.5535,0.5768,0.5841,0.5897],'b--v',label='DSH-A')
drh = plt.plot(x,[0.5428,0.5578,0.5673,0.5698],'y-v',label='DRH')
ash = plt.plot(x,[0.5946,0.5980,0.6013,0.6233],'r-^',label='ASH-L(our)')
plt.xticks(x)
plt.title('mAP')
plt.legend()
# 6
plt.subplot(2, 3, 6)
lsh = plt.plot(x,[0.5455,0.5876,0.6157,0.6256],'k-v',label='LSH')
mhf = plt.plot(x,[0.6168,0.6337,0.6612,0.6986],'c-v',label='MHF')
dpsh = plt.plot(x,[0.8029,0.8101,0.8225,0.8325],'g-v',label='DPSH')
dpsha = plt.plot(x,[0.7764,0.7812,0.7967,0.8007],'g--v',label='DPSH-A')
dsh = plt.plot(x,[0.8341,0.8366,0.8418,0.8522],'b-v',label='DSH')
dsha = plt.plot(x,[0.8542,0.8668,0.8741,0.8897],'b--v',label='DSH-A')
drh = plt.plot(x,[0.8343,0.8425,0.8476,0.8498],'y-v',label='DRH')
ash = plt.plot(x,[0.8707,0.8830,0.8932,0.9025],'r-^',label='ASH-L(our)')
plt.xticks(x)
plt.title('mRR')
plt.legend()


plt.legend()
plt.show()

# %%
import pandas as pd
import os
import cv2
#Read data with List storage N:[name],I:[img],Y[type]
root_dir = '/data/fjsdata/fundus/iSee/iSee_multi_dataset/' #the path of images
testset = pd.read_csv("/data/fjsdata/fundus/iSee/iSee_multi_dataset/CBIR_iSee_test.csv" , sep=',')#load testset
img_norm = []
img_path = []
for iname, itype in np.array(testset).tolist():
    if itype =='AMD':
        image_dir = root_dir+'img_data_%s'%itype
        image_path = os.path.join(image_dir, iname)
        #plt.imshow(cv2.imread(image_path))
        img_path.append(image_path)
        img_norm.append(cv2.imread(image_path))

# %%
plt.figure(figsize=(20,100))

# 1
plt.subplot(1, 5, 1)
plt.imshow(img_norm[1])
plt.ylabel('ASOCT-Cataract')
plt.axis('off')
plt.title('Top-1')
# 2
plt.subplot(1, 5, 2)
plt.imshow(img_norm[2])
plt.axis('off')
plt.title('Top-2')
# 3
plt.subplot(1, 5, 3)
plt.imshow(img_norm[3])
plt.axis('off')
plt.title('Top-3')
# 4
plt.subplot(1, 5, 4)
plt.imshow(img_norm[4])
plt.axis('off')
plt.title('Top-4')
# 5
plt.subplot(1, 5, 5)
plt.imshow(img_norm[6])
plt.axis('off')
plt.title('Top-5')

plt.show()

# %%
from IPython.display import Image
Image(filename='/data/fjsdata/fundus/iSee/iSee_multi_dataset/img_data_AMD/82132.jpg')
